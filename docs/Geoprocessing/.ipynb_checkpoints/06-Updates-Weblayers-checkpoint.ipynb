# %%
# import the GIS class in gis module
from arcgis.gis import GIS
from arcgis.features import FeatureLayerCollection
from time import strftime
import os, requests, zipfile
import pandas as pd
import geopandas as gpd
import arcpy,datetime,json

# %% [markdown]
# ## Download data

# %%
feature_layer_id = "062eaa4b57024dffa9a77822986a86a7"
# download_url = f"https://www.pasda.psu.edu/download/dep/StorageTankLocations_Active{strftime('%Y')}_{strftime('%m')}.zip"
download_url = f"https://www.pasda.psu.edu/download/dep/StorageTankLocations_Active2024_05.zip"
download_path = os.path.abspath("./assets")

# Filename from the URL
filename = download_url.split('/')[-1]

# Full path to save the file
file_path = os.path.join(download_path, filename)

# Download the file
response = requests.get(download_url)

# Check if the request was successful
if response.status_code == 200:
    # Write content to the file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print(f"File downloaded successfully to: {file_path}")
else:
    print("Failed to download the file.")
# Out:
# File downloaded successfully to: D:\Eric-Personal\python\docs\Geoprocessing\assets\StorageTankLocations_Active2024_05.zip

# %% [markdown]
# ## unzip downloaded data

# %%
# Extract the downloaded ZIP file
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(download_path)

# Path to the extracted CSV file
shp_file_path = os.path.join(download_path, "StorageTankLocations_Active2024_05.shp")

# Read the downloaded CSV data
downloaded_data = gpd.read_file(shp_file_path)
print(downloaded_data.shape)
downloaded_data.head()
# Out:
# (11289, 25)
#   FACILITY_I                     FACILITY_N                       FACILITY_A  \
# 0   56-39595                     CHEMSTREAM  NORTH STAR IND PARK COMMERCE DR
# 1   35-52629       THROOP DIVERSION CHAMBER                862 ENTERPRISE ST
# 2   11-39625       MARTIN GENERAL STORE 230           4057 ADMIRAL PEARY HWY
# 3   15-39634  FREEDOM VILLAGE AT BRANDYWINE                  15 FREEDOM BLVD
# 4   45-39639             ROCK HILL CONCRETE         UPPER CHERRY VALLEY ROAD
#
#     FACILITY_1       FACILITY_C FACILITY_S  FACILITY_Z  COUNTY_ID  FACILITY_2  \
# 0         None        STOYSTOWN         PA       15563       2463    Somerset
# 1         None     DICKSON CITY         PA       18519       2442  Lackawanna
# 2         None        EBENSBURG         PA  15931-3919       2418     Cambria
# 3         None  WEST BRANDYWINE         PA  19320-1549       2422     Chester
# 4  RD4 BOX 140      STROUDSBURG         PA       18360       2452      Monroe
#
#    MUNICIPALI  ... TANK_OWN_3       TANK_OWN_4  TANK_OWN_5  TANK_OWN_6  \
# 0        2130  ...       None       HOMER CITY          PA  15748-1422
# 1        1403  ...       None         OLYPHANT          PA  18447-0280
# 2         570  ...       None         BELLWOOD          PA  16617-1922
# 3         753  ...       None  WEST BRANDYWINE          PA  19320-1549
# 4        1781  ...       None    DOWNERS GROVE          IL  60515-5560
#
#   PRIMARY_FA SITE_ID   LATITUDE  LONGITUDE  \
# 0     695172  691484  40.137605 -79.025093
# 1     695938  645882  41.461955 -75.616175
# 2     696735  693483  40.460940 -78.769425
# 3     697311  694230  40.013371 -75.790556
# 4     697481  694449  40.927418 -75.271720
#
#                                           TANK_INFOR  \
# 0  http://cedatareporting.pa.gov/Reportserver/Pag...
# 1  http://cedatareporting.pa.gov/Reportserver/Pag...
# 2  http://cedatareporting.pa.gov/Reportserver/Pag...
# 3  http://cedatareporting.pa.gov/Reportserver/Pag...
# 4  http://cedatareporting.pa.gov/Reportserver/Pag...
#
#                            geometry
# 0  POINT (-8797033.113 4885958.858)
# 1  POINT (-8417554.097 5080720.569)
# 2  POINT (-8768572.281 4933152.658)
# 3  POINT (-8436966.101 4867885.507)
# 4  POINT (-8379209.542 5001641.723)
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Log into ArcGIS Online

# %%
gis = GIS("home")
print("Logged in as " + str(gis.properties.user.username))
# Out:
# Logged in as yxy180050@utdallas.edu_UTDEPPS

# %%
# Get the existing feature layer data

data_item = gis.content.get(itemid=feature_layer_id)
feature_layer = data_item.layers[0]

# Query all data from the existing feature layer including geometry
existing_data = pd.DataFrame.spatial.from_layer(feature_layer)
print(existing_data.shape)
existing_data.head()
# Out:
# (11287, 26)
#    COUNTY_ID FACILITY_1    FACILITY_2              FACILITY_A    FACILITY_C  \
# 0       2414                    Blair      200 E CHESTNUT AVE       ALTOONA
# 1       2414                    Blair     7043 ELLENBERGER DR       ALTOONA
# 2       2474                     York      629 LOUCKS MILL RD          YORK
# 3       2430                 Delaware  145 KING OF PRUSSIA RD        RADNOR
# 4       2458             Philadelphia          401 N BROAD ST  PHILADELPHIA
#
#   FACILITY_I         FACILITY_M                FACILITY_N FACILITY_S  \
# 0   07-39517       Altoona City     MARTINS FOOD MKT 6292         PA
# 1   07-39510      Allegheny Twp                SEL LO OIL         PA
# 2   67-39526  Spring Garden Twp          KINSLEY CONCRETE         PA
# 3   23-39588         Radnor Twp  145 KING OF PRUSSIA ROAD         PA
# 4   51-39661  Philadelphia City    LEVEL 3 COMMUNICATIONS         PA
#
#    FACILITY_Z  ...                                              SHAPE  \
# 0  16601-5204  ...  {"x": -8726458.4479, "y": 4942726.704800002, "...
# 1  16601-9357  ...  {"x": -8730042.6016, "y": 4933846.043899998, "...
# 2  17403-1010  ...  {"x": -8540841.212, "y": 4862130.322300002, "s...
# 3  19087-4557  ...  {"x": -8388575.740900001, "y": 4871738.2080999...
# 4  19108-1001  ...  {"x": -8366988.442600001, "y": 4860082.0562999...
#
#    SITE_ID                                         TANK_INFOR  TANK_OWNER  \
# 0   648049  http://cedatareporting.pa.gov/Reportserver/Pag...       69978
# 1   686086  http://cedatareporting.pa.gov/Reportserver/Pag...      141859
# 2   554467  http://cedatareporting.pa.gov/Reportserver/Pag...       32864
# 3   602791  http://cedatareporting.pa.gov/Reportserver/Pag...      278309
# 4   239947  http://cedatareporting.pa.gov/Reportserver/Pag...      136129
#
#                    TANK_OWN_1                  TANK_OWN_2 TANK_OWN_3  \
# 0                GIANT CO LLC        1149 HARRISBURG PIKE
# 1              SEL LO OIL INC                RR 2 BOX 629
# 2    UNIVAR SOLUTIONS USA LLC  3075 HIGHLAND PKWY STE 200
# 3         TRUSTEES UNIV OF PA              102 PENN TOWER
# 4  LEVEL 3 COMMUNICATIONS LLC          1025 ELDORADO BLVD
#
#       TANK_OWN_4 TANK_OWN_5  TANK_OWN_6
# 0       CARLISLE         PA  17013-1607
# 1        ALTOONA         PA  16601-9357
# 2  DOWNERS GROVE         IL  60515-5560
# 3   PHILADELPHIA         PA       19104
# 4     BROOMFIELD         CO  80021-8254
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Make a backup Layer

# %%
try:
    # Check if a feature layer with the same name already exists
    new_feature_layer_name = "Backup_FeatureLayer"
    existing_layers = gis.content.search(query=new_feature_layer_name, item_type="Feature Service")
    
    # If a feature layer with the same name exists, delete it
    for item in existing_layers:
        item.delete()
    
    # Create a new hosted feature layer
    new_feature_layer_item = existing_data.spatial.to_featurelayer(new_feature_layer_name, folder = "ArcGIS Python API")
    print("Created the new feature layer service successfully.")
    
except Exception as e:
    print(f"Error creating the new feature layer: {e}")
# Out:
# Created the new feature layer service successfully.

# %% [markdown]
# ## Copy everything in the existing layer to the backup layer

# %%
new_feature_layer_item
# Out:
# <Item title:"Backup_FeatureLayer" type:Feature Layer Collection owner:yxy180050@utdallas.edu_UTDEPPS>

# %%
# # Define the schema for the new layer based on the existing layer
# fields = [{"name": field['name'], "type": field['type'], "alias": field['alias']} for field in feature_layer.properties.fields]
# geometry_type = feature_layer.properties.geometryType

# layer_definition = {
#     "layers": [{
#         "name": "BackupLayer",
#         "geometryType": geometry_type,
#         "fields": fields
#     }]
# }

# # Add the layer definition to the new feature layer collection
# new_feature_layer_collection.manager.add_to_definition(layer_definition)

# %%
# # Convert the DataFrame to a list of dictionaries
# features = existing_data.spatial.to_featureset().features

# # Define a function to chunk data
# def chunk_data(data, chunk_size):
#     for i in range(0, len(data), chunk_size):
#         yield data[i:i + chunk_size]

# # Set the chunk size
# chunk_size = 100  # Adjust the chunk size as necessary

# try:
#     # Get the layer in the new feature layer collection
#     new_layer = new_feature_layer_collection.layers[0]

#     # Add features in chunks
#     for chunk in chunk_data(features, chunk_size):
#         new_layer.edit_features(adds=chunk)
#     print("Successfully added all features to the new layer.")

# except Exception as e:
#     print(f"Error: {e}")

# %%
# features[0]

# %% [markdown]
# ## Check the difference between exisitng data and downloaded data

# %%
# Convert column names to lowercase for comparison
existing_columns= existing_data.columns
downloaded_columns = downloaded_data.columns

# Find columns in downloaded_data that are present in existing_data
checking_col = downloaded_columns[downloaded_columns.isin(existing_columns)]

checking_col
# Out:
# Index(['FACILITY_I', 'FACILITY_N', 'FACILITY_A', 'FACILITY_1', 'FACILITY_C',
#        'FACILITY_S', 'FACILITY_Z', 'COUNTY_ID', 'FACILITY_2', 'MUNICIPALI',
#        'FACILITY_M', 'REG_EXPIRA', 'TANK_OWNER', 'TANK_OWN_1', 'TANK_OWN_2',
#        'TANK_OWN_3', 'TANK_OWN_4', 'TANK_OWN_5', 'TANK_OWN_6', 'PRIMARY_FA',
#        'SITE_ID', 'LATITUDE', 'LONGITUDE', 'TANK_INFOR'],
#       dtype='object')

# %%
# Identify new rows in the downloaded data
new_rows = downloaded_data[~downloaded_data[checking_col].apply(tuple, axis=1).isin(existing_data[checking_col].apply(tuple, axis=1))].dropna()
new_rows.shape
# Out:
# (35, 25)

# %%
new_rows.index
# Out:
# Index([  290,   291,   627,   889,  1013,  1654,  1680,  1745,  1900,  3308,
#         3475,  3698,  4309,  4807,  5788,  6799,  7044,  7201,  7577,  7620,
#         7985,  8038,  9042,  9221,  9239,  9485,  9651,  9798, 10631, 10712,
#        10769, 10798, 10889, 10991, 11175],
#       dtype='int64')

# %% [markdown]
# ## Overwrite features

# %% [markdown]
# ### Make a backup Layer

# %%
# Append new rows to the existing data
combined_data = pd.concat([existing_data, new_rows], ignore_index=True)
print(combined_data.shape)
combined_data.head()
# Out:
# (11322, 27)
#    COUNTY_ID FACILITY_1    FACILITY_2              FACILITY_A    FACILITY_C  \
# 0       2414                    Blair      200 E CHESTNUT AVE       ALTOONA
# 1       2414                    Blair     7043 ELLENBERGER DR       ALTOONA
# 2       2474                     York      629 LOUCKS MILL RD          YORK
# 3       2430                 Delaware  145 KING OF PRUSSIA RD        RADNOR
# 4       2458             Philadelphia          401 N BROAD ST  PHILADELPHIA
#
#   FACILITY_I         FACILITY_M                FACILITY_N FACILITY_S  \
# 0   07-39517       Altoona City     MARTINS FOOD MKT 6292         PA
# 1   07-39510      Allegheny Twp                SEL LO OIL         PA
# 2   67-39526  Spring Garden Twp          KINSLEY CONCRETE         PA
# 3   23-39588         Radnor Twp  145 KING OF PRUSSIA ROAD         PA
# 4   51-39661  Philadelphia City    LEVEL 3 COMMUNICATIONS         PA
#
#    FACILITY_Z  ...  SITE_ID  \
# 0  16601-5204  ...   648049
# 1  16601-9357  ...   686086
# 2  17403-1010  ...   554467
# 3  19087-4557  ...   602791
# 4  19108-1001  ...   239947
#
#                                           TANK_INFOR  TANK_OWNER  \
# 0  http://cedatareporting.pa.gov/Reportserver/Pag...       69978
# 1  http://cedatareporting.pa.gov/Reportserver/Pag...      141859
# 2  http://cedatareporting.pa.gov/Reportserver/Pag...       32864
# 3  http://cedatareporting.pa.gov/Reportserver/Pag...      278309
# 4  http://cedatareporting.pa.gov/Reportserver/Pag...      136129
#
#                    TANK_OWN_1                  TANK_OWN_2 TANK_OWN_3  \
# 0                GIANT CO LLC        1149 HARRISBURG PIKE
# 1              SEL LO OIL INC                RR 2 BOX 629
# 2    UNIVAR SOLUTIONS USA LLC  3075 HIGHLAND PKWY STE 200
# 3         TRUSTEES UNIV OF PA              102 PENN TOWER
# 4  LEVEL 3 COMMUNICATIONS LLC          1025 ELDORADO BLVD
#
#       TANK_OWN_4  TANK_OWN_5  TANK_OWN_6  geometry
# 0       CARLISLE          PA  17013-1607      None
# 1        ALTOONA          PA  16601-9357      None
# 2  DOWNERS GROVE          IL  60515-5560      None
# 3   PHILADELPHIA          PA       19104      None
# 4     BROOMFIELD          CO  80021-8254      None
#
# [5 rows x 27 columns]

# %%
new_feature_layer_item = combined_data.spatial.to_featurelayer(new_feature_layer_name, folder = "ArcGIS Python API")
# Out:
# The operation was attempted on an empty geometry.
# The operation was attempted on an empty geometry.

# %%
# try:
#     # Get the feature layer collection
#     featureLayerCollection = FeatureLayerCollection.fromitem(new_feature_layer_item)
    
#     # Overwrite the feature layer with the shapefile
#     featureLayerCollection.manager.overwrite(shp_file_path)
#     print("Feature layer updated successfully.")
# except Exception as e:
#     print(f"Error creating or updating the new feature layer: {e}")
# Out:
# Error creating or updating the new feature layer: Error while analyzing File Geodatabase 'StorageTankLocations_Active2024_05.shp' Unable to extract 'file geodatabase' Invalid File Geodatabase, missing gdbtable or gdbindexes file.
# (Error Code: 406)

# %%
os.remove(shp_file_path)
