# %% [markdown]
# <a href="https://colab.research.google.com/github/gisynw/ssj-30262/blob/main/docs/Lectures/Week04_JavaScript.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" style="height: 30px;"/>
# </a>
# &nbsp &nbsp
# <a href="./Week04_JavaScript.ipynb" target="_blank">
#   <img src="https://img.icons8.com/?size=100&id=108635&format=png&color=000000" alt="Download" style="height: 40px;"/>
#  </a>

# %% [markdown]
# ### What is JavaScript (JS)
#
# JavaScript is a scripting language used to create dynamic content on web pages. It can interact with HTML and CSS to enhance user experiences
#
# JS code is between `<script>` and `</script>` tags
#
# ### Writing a JavaScript Program
# - Scripts can be placed in the `<body>`, or in the `<head>` section of an HTML page
#
# - Saved in external files and access an external script
# `<script src = "" ></script>`

# %% [markdown]
# ### JavaScript Syntax
# - JavaScript command lines end with a semicolon to separate it from the next command line in the program

# %% [markdown]
# ### JavaScript Basics
# #### Variables
# Variables are used to store values: `const`, `var`, `let`,
# - The 'var' was used in JS from 1995 to 2015, now should only be used in code for older browsers
# - The 'let' and 'const' was added to JS in 2015
# - Always use `const` if the value should not be changed
#
# #### Type of Variables
# - Numeric
# - String
# - Boolean
# - Null

# %% [markdown]
# ### Exercise 1: Assign variable
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Methods and Values
# - Methods are __actions__ you can perform on HTML element
#
# - Properties are __values__ that you can change

# %% [markdown]
# #### Change the content of the element
# - Change the property of the `<p>` element with id='location'
#
# - The most common way to access an element is to use the `id` of the element
#
# - The `innerHTML` is used to get the values of element

# %% [markdown]
# ### Exercise 2:  updates the content of an HTML element
# - documnet: the whole HTML document
# - .getElementById("myloc"): finds the HTML element that has the ID "myloc"
# - .innerHTML is a property that allows us to set or get the HTML content inside the selected element
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Function
# A JS function is a reusable block of code designed to perform a particular task
#
# Functions allow developers to organize the reuse code efficiently
#
# Syntax:

# %% [markdown]
# #### Function Declaration
#
# 1. Function format
#
# function name(parameter1, parameter2,...){
#
#  &nbsp; __code to be executed__
#
# }
#
# 2. Call function
#
# name();

# %% [markdown]
# ### Exercise 3: Create a simple function
# - Rewrite above code in function format
# ![image-2.png](attachment:image-2.png)
#
# - Try a differnet simple function
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 4. Update Time Automatically
# - Update the year automatically
# - Using `document` object, `write` method
# - new Date() return the current date
# - .getFullYear() get the current year from the date
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Events in JS
# Events are things that happen in the web page you are programming
#
# - The user selects, clicks, or hovers the cursor over a certain element
#
# - Common events: `onclick`, `onmouseover`, `onchange`
#
# HTML allows event handler attributes, with JavaScript code, to be added to HTML elements.
#
# `<element event='some JavaScript'>`

# %% [markdown]
# ### Exercise 5: Add events to button
# 5.1 Create a button
#
# ![image-5.png](attachment:image-5.png)
#
# 5.2 Set up where the message appear
#
# ![image-3.png](attachment:image-3.png)
#
# 5.3 JavaScript to Handle Events
#
# Next, add JavaScript to make the button functional. This script will listen for the click event and display a message
#
# The `onclick` event occurs when the user clicks on an HTML element
#
# ![image.png](attachment:image.png)
#
# 2nd Syntax: Add events to button through function
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Objects in JS
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Button
# #### show something through the Button

# %% [markdown]
# #### Back to top
# - set up a button
# - when the button appear
# - what happen when button is clicked
