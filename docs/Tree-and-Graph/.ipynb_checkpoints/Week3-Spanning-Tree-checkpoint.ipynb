# %% [markdown]
# ## Minimum Spanning Trees (MST)
# ### Definition
# ![image.png](attachment:b14e125f-0519-492a-b642-b78c4a40998e.png)

# %% [markdown]
# ### Example
# ![image.png](attachment:53346b5b-76a1-4657-846a-40140f76f6a4.png)
# ![image.png](attachment:2b7a099d-274e-4778-aadd-994aa98ead8a.png)

# %% [markdown]
# ### How to verify the MST
# ![image.png](attachment:d5857dab-dab3-4d87-bb7f-c1a61ace4dfa.png)
# ![image.png](attachment:3963fc75-663b-4a39-8ee0-c0da3aa5c45e.png)
# ![image.png](attachment:c97bf8f7-7fa4-4e9b-8e8c-bb1e8fefc67f.png)
# ![image.png](attachment:5db597fa-6f4c-4038-99e1-11e9fbce94e0.png)

# %% [markdown]
# ## Prim's Algorithm
# ### Layzy Version
# * Running Time: $O(|E|∗log⁡(|E|))$
# ![image.png](attachment:7a4e8d6f-9fc8-4887-b627-e5d62802020b.png)
# ![image.png](attachment:8512adfe-c487-44f7-a56b-2d2bb93d1c84.png)![image.png](attachment:006eeaa0-7746-4d07-8011-62cda4ff5223.png)

# %% [markdown]
# ### Eager Version
# ![image.png](attachment:efc8349c-b3b9-4403-bdea-11cd67918762.png)
# ![image.png](attachment:31d913af-4483-4ced-8281-454f7997a2cf.png)

# %% [markdown]
# ## Kruskal's Algorithm
# * Time Complexity $O(|E|*log|E|)$
# ![image.png](attachment:b0524e76-8471-4dbf-b64c-f27760e280bf.png)
# ![image.png](attachment:81fb0885-f689-479d-9383-f11bc39d2511.png)
