# %% [markdown]
# ## Definition
# ![image.png](attachment:45a6394b-7656-4da8-abf2-b3c0a08e2614.png)

# %% [markdown]
# ## Example
# ![image.png](attachment:2c2274be-fa1b-45e1-8e17-f04009efc447.png)

# %% [markdown]
# ## Another Example
# ![image.png](attachment:eda071db-d0ed-4cc5-ac86-f4267a7ba471.png)
