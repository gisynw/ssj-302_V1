# %% [markdown]
# ## Topological-Sorting
# ### Definition
# ![image.png](attachment:0077920f-e4b3-413d-9394-2952d83778b9.png)

# %% [markdown]
# ### How to find it
# ![image.png](attachment:8b6c8ad2-a37a-491c-8f95-33c3002cd882.png)
