# %% [markdown]
# ## Graph
# ### Definition
# ![image.png](attachment:82a533db-642f-4989-a372-94f3d93284f3.png)

# %% [markdown]
# ### Example
# #### Directed Graph
# - Asymmetric Relationship
# #### Undirected graph
# - Symmetric Relationship
#
# ![image.png](attachment:075b0698-3a7d-46a9-8da0-56cf73958802.png)

# %% [markdown]
# ### Typical Representation of graph
# ![image.png](attachment:66e0077d-36ad-4042-b1e4-4afaf7a2d9f1.png)

# %% [markdown]
# ### Typical Problem in graph
# ![image.png](attachment:1cb9a50d-0322-4640-b3e0-1cd9fc6a7599.png)

# %% [markdown]
# ### How to represent it in Computer
# #### Adjacency matrix
# ![image.png](attachment:b8cf7935-6c52-45d5-9215-649bae54929e.png)
# - Quiz
# ![image.png](attachment:f95a6b40-6951-41ff-abfc-117903e5c8b5.png)

# %% [markdown]
# #### Adjacency List representation
# ![image.png](attachment:f7d45c84-7040-4fef-bad5-e28daf469c74.png)
#
# - Quiz
# ![image.png](attachment:744ea21b-59c8-4d53-8e82-b0f3426e4011.png)

# %% [markdown]
# ### Graph Traversals
# ![image.png](attachment:a1bbf444-19b2-4978-be19-47ce2d086498.png)

# %% [markdown]
# ### Breadth First Search
# #### Definition
# ![image.png](attachment:df658fef-3cd0-478a-ac84-3bbd31f772eb.png)
# #### Example
# <img src="attachment:53ac7b05-7a7f-41e7-aeef-b31146558585.png"  width="300" height="300">

# %% [markdown]
# #### Variable of each node
# ![image.png](attachment:b15d2f27-c24f-46b2-a472-6d8182536090.png)
# #### Pseudocode
# ![image.png](attachment:e3c7a902-bc19-4e18-95e6-a45ac94707c2.png)

# %% [markdown]
# ### Depth Frist Search
# #### Definition
# ![image.png](attachment:b63ff23d-ab2b-43e0-9f6b-2547ab35203f.png)
# #### BFS and DFS Tree
# ![image.png](attachment:ca80e488-f885-416e-9c79-5c5d53026ff5.png)

# %% [markdown]
# #### Example
# ![image.png](attachment:b42d2aba-f6d2-4f94-a6d0-a389956a15f5.png)
# #### Variables of each node
# ![image.png](attachment:ec476ddc-1b12-41d5-b16c-b9827695501b.png)
# ![image.png](attachment:cae28a01-64f4-4128-af53-6caaf49d5a25.png)

# %% [markdown]
# #### Pseudo Code
# ![image.png](attachment:0fe3d5c8-26c1-4b36-8f91-bb207ba9a8c4.png)
