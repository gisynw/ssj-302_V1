# %% [markdown]
# ## Definition
# ![image.png](attachment:2d615996-5b16-4978-95b9-2f1c305e1736.png)
# ### Quiz
# * 1
# ![image.png](attachment:0d445738-1e83-481f-96f2-934af1708559.png)
# ![image.png](attachment:b2654b50-ce7d-48ed-8594-5f8211f940d3.png)
# * 2
# ![image.png](attachment:a41aaca6-87ae-4aad-b681-e7efcfe0cda6.png)

# %% [markdown]
# ## Minimum Strongly Connected Component(MSCC)
# ![image.png](attachment:1a5689ab-308d-4cf2-8457-27297e622410.png)
# ![image.png](attachment:bafa31c0-2954-4d06-9bf1-dd5f39741e51.png)

# %% [markdown]
# ## How to find MSCC
# Assume we have try to find the MSCC of the following graph
# ![image.png](attachment:bf8b1438-675c-47b1-9826-5f242b657934.png)

# %% [markdown]
# ![image.png](attachment:0ca7331c-ac22-4a0c-bcdc-e239f61c437b.png)
