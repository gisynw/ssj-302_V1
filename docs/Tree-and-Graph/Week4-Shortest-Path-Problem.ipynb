# %% [markdown]
# ## Definition
# ![image.png](attachment:23996995-85d8-4fe9-be7f-32917ca90941.png)

# %% [markdown]
# ## Types
# ![image.png](attachment:6616d37c-6dd1-4a19-9fae-30ae6ad1f868.png)

# %% [markdown]
# ## The Property of Shortest Path
# ![image.png](attachment:fc8d1f21-1ece-4d39-9808-3674b715bafc.png)

# %% [markdown]
# ## Shortest Path on DAGs
# * (Directed Acyclic Graph)
# ![image.png](attachment:1b2d85f6-63af-4406-a2f3-abe3af0cad2a.png)
