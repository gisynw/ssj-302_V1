# %% [markdown]
# ## Definition
# ![image.png](attachment:ca0ab3d8-374c-4d84-8392-285d13e683fa.png)

# %% [markdown]
# ## Steps
# ![image.png](attachment:4ec151c2-44f4-41ca-bc7f-61f78846efaf.png)

# %% [markdown]
# ![image.png](attachment:e95f113b-cf88-4b0c-bf53-e84f8cb3b9e7.png)

# %% [markdown]
# ## Check the shortest path
# ![image.png](attachment:6f66d628-a38c-46a7-9d97-09d426530bca.png)

# %% [markdown]
# ## Quiz
# * 1
# ![image.png](attachment:298bdeca-93aa-4d4d-8811-63e4c7a24b15.png)
# * 2
# ![image.png](attachment:d1fe0178-a6bc-46d9-be26-2c349385bfc7.png)
# * 3
# ![image.png](attachment:6e29925c-656d-4a46-a7dc-bad6072197a4.png)
