# %% [markdown]
# <a href="https://colab.research.google.com/github/gisynw/ssj-30262/blob/main/docs/Demo/Week02_Personal_Website.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" style="height: 30px;"/>
# </a>
# &nbsp &nbsp
# <a href="./Week02_Personal_Website.ipynb" target="_blank">
#   <img src="https://img.icons8.com/?size=100&id=108635&format=png&color=000000" alt="Download" style="height: 40px;"/>
#  </a>

# %% [markdown]
# ### 1. Create a repo in GitHub
# #### 1.1 Create a new repo in GitHub
# 1. Createa repo which name should be _username_.github.io, where username is your username (or organization name) on GitHub.
#
# ![image.png](attachment:image.png)
#
# 2. Select 'Public'
#
# 3. Select 'Add README file'

# %% [markdown]
# ### 2. Check url of your personal website
#
# 1. Go to Seting of your repo
#
# 2. Go to Pages on the left side bar
#
# 3. Check the url of your personal website (The url does not generate immediately, you can check progress in action)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 3. Clone your repo to local computer
# ```bash
# git clone <url>
# ```

# %% [markdown]
# ### 4. HTML page
# #### 4.1 What is html?
# - Hyper Text Markup Language
# - It is used for creating web pages
# - Describes the structure of a web page
# - Consists of a series of elements
#
# #### 4.2 HTML Page Structure
#
# - The html document itself begins with `<html>` and ends with `<html>`
#
# - Content inside `<head>`
#
# - Content inside the `<title>` shown in the browser's title bar
#
# - Content inside the `<body>` section will be displayed in a browser
#
# ![image.png](attachment:image.png)
#
# [Source](https://www.w3schools.com/html/html_intro.asp)

# %% [markdown]
# #### 4.3 What is an HTML element?
# An HTML element is contained from start tag, and an end tag
#
# ```bash
# <tagname> Content goes here ... </tagname>
# ```
#
# `<html> Content </html>`
#
# `<head> Content </head>`
#
# `<body> Content </body>`

# %% [markdown]
# #### The `<!DOCTYPE>` Declaration
# The `<!DOCTYPE>` declaration represents the document type, and helps browsers to display web pages correctly.
#
# ```bash
# <!DOCTYPE html>
# ```

# %% [markdown]
# <h3 style="text-align: center;">Practice 1: Create a html and construct the basic structure</h3>
#
# 1. Create html file in VS Code
#
# The html file with name 'index.html' is recongizaed by GitHub as your personal website
#
# 2. Open html in VS Code
# Beofre you edit html in VS code, install severall extensions to power your VS Code
#
# Search extension from the left side panel:
#
# - Live Server: Launch local server
# - HTML Boilerplate: help on html editing
#
# 3. type __html__ and select __html5:boilerplate__
#
# 4. Understand the basic structure of html

# %% [markdown]
# ### `<head>` element
#
# #### 1. `<meta>` element
# - `<meta charset = 'UTF-8'>`: Specifies the character encoding for the HTML document
# - `<meta name="viewport" content="width=device-width, initial-scale=1.0">`
#     * __width=device-width__: sets the width of the page to follow the screen-width of the device
#     * __initial-scale=1.0__: the initial zoom level when the page is first loaded by the browser
#
# #### 2. `<title>` element
# - `<title>Personal Website</title>`

# %% [markdown]
# ### What inside the `<body>`?
#
# #### 1. `<header>` element
# - For introductory content or a set of navigation links
#
# #### 2. `<h1>` to `<h6>`
# - `<h1>Heading 1</h1>`
# - `<h5>Heading 5</h5>`
#
# #### 3. `<p>`

# %% [markdown]
# ### HTML Attributes
# - Attributes provide additional information about elements
# - Attributes are always specified in the start tag
#
# #### Style
# - It used to add styles to an element: `<tagname style="property:value;">`
#
# `<h1 style="font-size:60px;">Heading 1</h1>`
#
# `<p style="font-size:60px;">Such a good day</p>`
#
# #### Image
# - specifies the path the image, width and height of the image (in pixels), alternate text for an image and tooltip for the text or image
#
# `<img src="img_university.jpg" width="300" height="200" alt = 'Clark'>`
#
# You can store image in Github and use the relative path (without the "https://www part) as the link
#
# #### Hyperlink
# - Use words as a link
#
# `<a href="https://www.clarku.edu/" target ="_top">Clark University</a>`
#
# `target` Specify where to open the linked document
# _self: Default. Open in the same window
# _blank: Open in a new window
# _parent: Open in the parent frame
# _top: Open in the full body of the window
#
# - Use an image as a link
#
# `<a href="https://www.clarku.edu/" target ="_black"><img src="Images\clark.jpg" alt="clark"> </a>`
#
# - Link to an Email Address
#
# `<a href="mailto:someone@example.com">Send email</a>`
#
# #### `<style>`
# ##### background-color
# ##### Text-color
# ##### Fonts
#
# <p style="background-image: url('clark.jpg');">Clark</p>

# %% [markdown]
# ### Bookmark

# %% [markdown]
# [Comprehend list of HTML Tags](https://www.w3schools.com/tags/default.asp)
