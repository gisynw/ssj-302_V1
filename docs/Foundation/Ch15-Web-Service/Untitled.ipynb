# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#urllib.parse-module" data-toc-modified-id="urllib.parse-module-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><code>urllib.parse</code> module</a></span></li><li><span><a href="#Use-urllib.request-to-read-resources" data-toc-modified-id="Use-urllib.request-to-read-resources-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Use <code>urllib.request</code> to read resources</a></span><ul class="toc-item"><li><span><a href="#Send-Get" data-toc-modified-id="Send-Get-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Send <code>Get</code></a></span></li><li><span><a href="#Send-Post" data-toc-modified-id="Send-Post-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Send <code>Post</code></a></span></li><li><span><a href="#Send-Put" data-toc-modified-id="Send-Put-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Send <code>Put</code></a></span></li><li><span><a href="#Multi-thread-download-unit" data-toc-modified-id="Multi-thread-download-unit-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Multi-thread download unit</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## `urllib.parse` module

# %%
from urllib.parse import *

# %%
result = urlparse('http://www.crazyit.org:80/index.php;yeeku?name=fkit#frag')
print(result)
# Out:
# ParseResult(scheme='http', netloc='www.crazyit.org:80', path='/index.php', params='yeeku', query='name=fkit', fragment='frag')

# %%
# use index or attributes name to get contents
print('scheme:',result.scheme,result[0])
print('host and port', result.netloc, result[1])
print('host',result.hostname)
print('port',result.port)
print('resource path',result.path,result[2])
print('parameter',result.params,result[3])
print('search string',result.query,result[4])
print('fragment:',result.fragment,result[5])
print(result.geturl())
# Out:
# scheme: http http
# host and port www.crazyit.org:80 www.crazyit.org:80
# host www.crazyit.org
# port 80
# resource path /index.php /index.php
# parameter yeeku yeeku
# search string name=fkit name=fkit
# fragment: frag frag
# http://www.crazyit.org:80/index.php;yeeku?name=fkit#frag

# %% [markdown]
# **`urlunparse()` is an opposite method to `urlparse()`, which combine parameters together to get the URL address**

# %%
result = urlunparse(('http','www.crazyit.org:80','index.php','yeeku','name=fkit','frag'))
print('url: ',result)
# Out:
# url:  http://www.crazyit.org:80/index.php;yeeku?name=fkit#frag

# %% [markdown]
# ## Use `urllib.request` to read resources

# %%
from urllib.request import *
# read the resource from url
result = urlopen('https://fkjava.org/')
data = result.read().decode('utf-8')
print(data)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#
#
#
#
#     <title>疯狂系列图书</title>
#
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#
#     <meta name="description" content="疯狂软件的官方网站">
# <meta property="og:type" content="website">
# <meta property="og:title" content="疯狂系列图书">
# <meta property="og:url" content="https:&#x2F;&#x2F;fkjava.org&#x2F;index.html">
# <meta property="og:site_name" content="疯狂系列图书">
# <meta property="og:description" content="疯狂软件的官方网站">
# <meta property="og:locale" content="zh_CN">
# <meta property="article:author" content="疯狂软件">
# <meta property="article:tag" content="疯狂软件">
# <meta property="article:tag" content="疯狂Java">
# <meta property="article:tag" content="疯狂Python">
# <meta property="article:tag" content="Java学习">
# <meta property="article:tag" content="Python学习">
# <meta name="twitter:card" content="summary">
#
#
#
#
#
#
#
# ...

# %%
# use context manager to read the url resource
with urlopen('https://fkjava.org/') as f:
    data = f.read()
    print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#
#
#
#
#     <title>疯狂系列图书</title>
#
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#
#     <meta name="description" content="疯狂软件的官方网站">
# <meta property="og:type" content="website">
# <meta property="og:title" content="疯狂系列图书">
# <meta property="og:url" content="https:&#x2F;&#x2F;fkjava.org&#x2F;index.html">
# <meta property="og:site_name" content="疯狂系列图书">
# <meta property="og:description" content="疯狂软件的官方网站">
# <meta property="og:locale" content="zh_CN">
# <meta property="article:author" content="疯狂软件">
# <meta property="article:tag" content="疯狂软件">
# <meta property="article:tag" content="疯狂Java">
# <meta property="article:tag" content="疯狂Python">
# <meta property="article:tag" content="Java学习">
# <meta property="article:tag" content="Python学习">
# <meta name="twitter:card" content="summary">
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ###  Send `Get`
# * Use `urlopen` to send `Get` requirement with parameters to server

# %%
import urllib.parse

# %%
params = urllib.parse.urlencode({'name':'fkit','password':'123888'})
# add parameter to request
url = 'http://localhost:8888/test/get.jsp?%s' %params
print(url)
# Out:
# http://localhost:8888/test/get.jsp?name=fkit&password=123888

# %% [markdown]
# **We have not deploy this server as the localhost yet**

# %%
# with urlopen(url = url) as f:
#     print(f.read().decode('utf-8'))

# %% [markdown]
# ###  Send `Post`
# * use `urlopen` to send `POST` requirement with parameters to server
# * use `data` in `urlopen`

# %%
params = urllib.parse.urlencode({'name':'fkit','password':'123888'})
params = params.encode('utf-8')
# input params as data
# with urlopen('https://fkjava.org/',data = params) as f:
#     print(f.read().decode('utf-8'))

# %% [markdown]
# ### Send `Put`

# %%
params = 'put parameters'.encode('utf-8')
# Create Request Object, Use PUT method
# req = urllib.request.Request(url = 'http://localhost:8888/test/put', data = params, method = 'PUT')`
# with urlopen(req) as f:
#     print(f.status)
#     print(f.read().decode('utf-8'))

# %% [markdown]
# ### Multi-thread download unit

# %%
import threading
class DownUtill:
    def __init__(self,path,target_file,thread_num):
        # Download path
        self.path = path
        # How many threads are using
        self.thread_num = thread_num
        # The save place
        self.target_file = target_file
        # initialize threads arrary
